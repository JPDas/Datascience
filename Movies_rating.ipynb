# %%
import pandas as pd

# %%
rating = pd.read_csv('Amazon - Movies and TV Ratings.csv')

# %%
rating.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9    ...     Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN    ...          NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN    ...          NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN    ...          NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN    ...          NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN    ...          NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# ...

# %%
rating.set_index('user_id', inplace=True)

# %%
#Handling of missing data 
missing_column = rating.isnull()

for missing in missing_column.columns.values.tolist():
    print(missing)
    print(missing_column[missing].value_counts())
# Out:
# Movie1
# True     4847
# False       1
# Name: Movie1, dtype: int64
# Movie2
# True     4847
# False       1
# Name: Movie2, dtype: int64
# Movie3
# True     4847
# False       1
# Name: Movie3, dtype: int64
# Movie4
# True     4846
# False       2
# Name: Movie4, dtype: int64
# Movie5
# True     4819
# False      29
# Name: Movie5, dtype: int64
# Movie6
# True     4847
# False       1
# Name: Movie6, dtype: int64
# Movie7
# True     4847
# False       1
# Name: Movie7, dtype: int64
# Movie8
# True     4847
# False       1
# Name: Movie8, dtype: int64
# Movie9
# True     4847
# False       1
# Name: Movie9, dtype: int64
# Movie10
# True     4847
# False       1
# Name: Movie10, dtype: int64
# Movie11
# True     4846
# False       2
# Name: Movie11, dtype: int64
# Movie12
# True     4843
# False       5
# Name: Movie12, dtype: int64
# Movie13
# True     4847
# False       1
# Name: Movie13, dtype: int64
# Movie14
# True     4847
# False       1
# Name: Movie14, dtype: int64
# Movie15
# ...

# %% [markdown]
# ### Which movies have maximum views/ratings?

# %%
max_ratting = {}
for movies in rating.columns.values.tolist():
    max_ratting[movies] = rating[rating[movies] == rating[movies].max()][movies].count()
    
print(max(max_ratting.items(), key=lambda k: k[1]))
# Out:
# ('Movie127', 1512)

# %% [markdown]
# ### What is the average rating for each movie? Define the top 5 movies with the maximum ratings.

# %%
columns = ['Mean', 'Review Count']
data = []
index = []
for movies in rating.columns.values.tolist():
    data.append([rating[movies].mean(), rating[rating[movies] >= rating[movies].mean()][movies].count()])
    index.append(movies)

avg_rating = pd.DataFrame(data, index=index, columns=columns)

# %%
avg_rating.head()
# Out:
#             Mean  Review Count
# Movie1  5.000000             1
# Movie2  5.000000             1
# Movie3  2.000000             1
# Movie4  5.000000             2
# Movie5  4.103448            20

# %%
data = avg_rating[avg_rating['Mean'] >= 4]
print(data.sort_values(by=['Review Count'], ascending=False).head())
# Out:
#               Mean  Review Count
# Movie127  4.111976          1512
# Movie140  4.833910           523
# Movie103  4.562500           215
# Movie29   4.806584           215
# Movie16   4.518750           213

# %% [markdown]
# ### Define the top 5 movies with the least audience.

# %%
print(data.sort_values(by=['Review Count']).head())
# Out:
#           Mean  Review Count
# Movie1     5.0             1
# Movie106   5.0             1
# Movie102   4.0             1
# Movie100   4.0             1
# Movie99    4.0             1

# %% [markdown]
# ### Recommender system is pending
