# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('clustering.csv')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
X = data[["LoanAmount","ApplicantIncome"]]

# %%
plt.figure(figsize=(12,6))
plt.scatter(X["ApplicantIncome"],X["LoanAmount"],c='black')
plt.xlabel('AnnualIncome')
plt.ylabel('Loan Amount (In Thousands)')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
X = data[['LoanAmount', 'ApplicantIncome']]

# %%
X
# Out:
#      LoanAmount  ApplicantIncome
# 0           128             4583
# 1            66             3000
# 2           120             2583
# 3           141             6000
# 4            95             2333
# 5            70             3200
# 6           109             2500
# 7           114             1853
# 8            17             1299
# 9           125             4950
# 10          100             3596
# 11           76             3510
# 12          133             4887
# 13          115             2600
# 14          104             7660
# 15          116             2600
# 16          112             3365
# 17          122             2799
# 18          110             4226
# 19           35             1442
# 20          120             3750
# 21           74             3167
# 22          106             4692
# 23          114             3500
# 24          100             1828
# 25          144             3667
# 26          110             3748
# 27           80             3600
# 28           47             1800
# 29           75             2400
# ..          ...              ...
# 351          84             2667
# 352         108             3675
# 353         132             5800
# 354         120             4467
# 355          70             3333
# 356         123             3400
# 357           9             2378
# 358         104             3166
# 359         150             6406
# 360         108             3159
# 361         136             3087
# 362         110             3229
# 363         107             1782
# 364          90             1836
# 365          36             3166
# 366          61             1880
# 367         146             2787
# 368         104             2297
# 369          70             2165
# 370          94             4750
# 371         106             2726
# 372          56             3000
# 373         142             3859
# 374         110             3833
# 375          88             2987
# 376         128             5703
# 377         108             3232
# 378          71             2900
# 379          40             4106
# 380         133             4583
#
# [381 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=2, init= 'k-mean++')

# %%
kmeans.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-28568fcd941d> in <module>
# ----> 1 kmeans.fit(X)
#
# C:\Anaconda\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# C:\Anaconda\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     378                 verbose=verbose, precompute_distances=precompute_distances,
#     379                 tol=tol, x_squared_norms=x_squared_norms,
# --> 380                 random_state=random_state)
#     381             # determine if these results are the best so far
#     382             if best_inertia is None or inertia < best_inertia:
#
# C:\Anaconda\lib\site-packages\sklearn\cluster\k_means_.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     434     # init
#     435     centers = _init_centroids(X, n_clusters, init, random_state=random_state,
# --> 436                               x_squared_norms=x_squared_norms)
#     437     centers = np.ascontiguousarray(centers)
#     438     if verbose:
#
# C:\Anaconda\lib\site-packages\sklearn\cluster\k_means_.py in _init_centroids(X, k, init, random_state, x_squared_norms, init_size)
#     760         raise ValueError("the init parameter for the k-means should "
#     761                          "be 'k-means++' or 'random' or an ndarray, "
# --> 762                          "'%s' (type '%s') was passed." % (init, type(init)))
#     763
#     764     if sp.issparse(centers):
#
# ValueError: the init parameter for the k-means should be 'k-means++' or 'random' or an ndarray, 'k-mean++' (type '<class 'str'>') was passed.
